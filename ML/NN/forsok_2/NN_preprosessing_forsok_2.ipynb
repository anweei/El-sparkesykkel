# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Restructuring raw dataframe ##

# %%
df_acc = pd.read_csv('csv/raw_acc_data.csv')
df_gyro = pd.read_csv('csv/raw_gyro_data.csv')

# %%
df_acc['label'] = df_acc['label'].map({'Normal': 0, 'Reckless': 1})
df_gyro['label'] = df_gyro['label'].map({'Normal': 0, 'Reckless': 1})

# %%
df_acc
# Out:
#              acc_z      acc_x      acc_y  label  sampleNum
# 0        -0.241627  -0.349282  11.913876      0          0
# 1         7.148325   2.514354  23.744019      0          0
# 2         5.229665   5.516746  14.444976      0          0
# 3        -2.071770   6.657895 -11.710526      0          0
# 4        -3.057416  14.755981 -18.251196      0          0
# ...            ...        ...        ...    ...        ...
# 1059595 -22.114833  25.684211 -73.834928      1       2648
# 1059596 -27.988038  26.559809 -61.370813      1       2648
# 1059597   7.586124   8.356459  37.992823      1       2648
# 1059598  24.210526   2.973684 -78.334928      1       2648
# 1059599  12.040670 -31.662679  19.911483      1       2648
#
# [1059600 rows x 5 columns]

# %%
df_gyro
# Out:
#           gyro_z    gyro_x    gyro_y  label  sampleNum
# 0       0.078723  1.382979 -0.037234      0          0
# 1       0.203191 -0.215957 -0.218085      0          0
# 2       0.060638  0.838298 -0.050000      0          0
# 3      -0.042553  0.610638 -0.374468      0          0
# 4       0.001064  0.442553 -0.219149      0          0
# ...          ...       ...       ...    ...        ...
# 529795 -0.038298  1.623404  0.287234      1       2648
# 529796  0.094681 -0.111702  0.093617      1       2648
# 529797 -0.029787  1.501064  0.421277      1       2648
# 529798  0.093617 -0.339362 -0.072340      1       2648
# 529799 -0.095745  0.938298  0.363830      1       2648
#
# [529800 rows x 5 columns]

# %% [markdown]
# ## Accelerometer y direction

# %%
acc_y_arr = df_acc['acc_y'].values

# %%
acc_y_list = acc_y_arr.tolist()

# %%
list_of_list = []
for i in range(2649):
    temp = acc_y_list[i*400:(i+1)*400]
    list_of_list.append(temp)

# %%
df_acc_y = pd.DataFrame(list_of_list)

# %%
df_acc_y
# Out:
#             0          1          2          3          4          5    \
# 0     11.913876  23.744019  14.444976 -11.710526 -18.251196  -5.318182
# 1     -4.011962   0.811005   3.818182   3.043062  -3.337321  -4.602871
# 2      0.203349  -4.311005  -9.643541  -7.545455   0.014354   0.533493
# 3      2.322967   1.626794   4.507177   1.940191   1.672249   4.119617
# 4     -1.854067  -1.856459  -3.129187   5.033493   3.210526   4.667464
# ...         ...        ...        ...        ...        ...        ...
# 2644   2.413876   2.724880   1.787081  -4.220096  -8.117225   2.251196
# 2645  -5.411483  -2.167464  -0.985646  -5.598086  -5.925837  -1.188995
# 2646   2.751196 -21.925837  -0.356459  25.834928  20.083732  -1.552632
# 2647  -3.770335   4.516746  -0.899522  -2.633971   2.710526  -2.770335
# 2648  -8.471292  -1.212919   7.925837  45.794258  58.332536  13.705742
#
#             6          7          8          9    ...        390        391  \
# ...

# %%
labels = list(df_acc['label'].values)
y = []
for i in range(2649):
    y.append(labels[i*400])

# %%
df_acc_y['y']=y

# %%
df_acc_y
# Out:
#               0          1          2          3          4          5  \
# 0     11.913876  23.744019  14.444976 -11.710526 -18.251196  -5.318182
# 1     -4.011962   0.811005   3.818182   3.043062  -3.337321  -4.602871
# 2      0.203349  -4.311005  -9.643541  -7.545455   0.014354   0.533493
# 3      2.322967   1.626794   4.507177   1.940191   1.672249   4.119617
# 4     -1.854067  -1.856459  -3.129187   5.033493   3.210526   4.667464
# ...         ...        ...        ...        ...        ...        ...
# 2644   2.413876   2.724880   1.787081  -4.220096  -8.117225   2.251196
# 2645  -5.411483  -2.167464  -0.985646  -5.598086  -5.925837  -1.188995
# 2646   2.751196 -21.925837  -0.356459  25.834928  20.083732  -1.552632
# 2647  -3.770335   4.516746  -0.899522  -2.633971   2.710526  -2.770335
# 2648  -8.471292  -1.212919   7.925837  45.794258  58.332536  13.705742
#
#               6          7          8          9  ...        391        392  \
# ...

# %%
df_acc_y.to_csv('csv/df_acc_y.csv')

# %% [markdown]
# ## Accelerometer x direction

# %%
acc_x_arr = df_acc['acc_x'].values

# %%
acc_x_list = acc_x_arr.tolist()

# %%
list_of_list = []
for i in range(2649):
    temp = acc_x_list[i*400:(i+1)*400]
    list_of_list.append(temp)

# %%
df_acc_x = pd.DataFrame(list_of_list)

# %%
df_acc_x
# Out:
#             0          1          2          3          4          5    \
# 0     -0.349282   2.514354   5.516746   6.657895  14.755981   7.576555
# 1      8.026316  12.789474   6.160287  12.715311   8.784689   8.904306
# 2     21.454545   8.978469  10.933014  16.102871   7.693780   4.258373
# 3      2.241627   4.870813  18.971292   0.253589   2.739234  14.265550
# 4      9.428230   2.468900   3.655502   8.043062  10.385167   4.889952
# ...         ...        ...        ...        ...        ...        ...
# 2644  -4.112440   9.583732  18.332536  -1.421053   2.988038  17.837321
# 2645   1.076555  12.114833  11.260766   1.918660  13.394737  13.358852
# 2646 -38.698565  14.294258  44.564593 -14.803828 -10.284689  30.337321
# 2647  10.315789  15.559809  -0.055024   5.724880   2.820574   1.007177
# 2648  15.208134   7.193780   7.636364  33.014354 -42.066986 -11.229665
#
#             6          7          8          9    ...        390        391  \
# ...

# %%
labels = list(df_acc['label'].values)
x = []
for i in range(2649):
    x.append(labels[i*400])

# %%
df_acc_x['x']=x

# %%
df_acc_x
# Out:
#               0          1          2          3          4          5  \
# 0     -0.349282   2.514354   5.516746   6.657895  14.755981   7.576555
# 1      8.026316  12.789474   6.160287  12.715311   8.784689   8.904306
# 2     21.454545   8.978469  10.933014  16.102871   7.693780   4.258373
# 3      2.241627   4.870813  18.971292   0.253589   2.739234  14.265550
# 4      9.428230   2.468900   3.655502   8.043062  10.385167   4.889952
# ...         ...        ...        ...        ...        ...        ...
# 2644  -4.112440   9.583732  18.332536  -1.421053   2.988038  17.837321
# 2645   1.076555  12.114833  11.260766   1.918660  13.394737  13.358852
# 2646 -38.698565  14.294258  44.564593 -14.803828 -10.284689  30.337321
# 2647  10.315789  15.559809  -0.055024   5.724880   2.820574   1.007177
# 2648  15.208134   7.193780   7.636364  33.014354 -42.066986 -11.229665
#
#               6          7          8          9  ...        391        392  \
# ...

# %% [markdown]
# ## Accelerometer z direction

# %%
acc_z_arr = df_acc['acc_z'].values

# %%
acc_z_list = acc_z_arr.tolist()

# %%
list_of_list = []
for i in range(2649):
    temp = acc_z_list[i*400:(i+1)*400]
    list_of_list.append(temp)

# %%
df_acc_z = pd.DataFrame(list_of_list)

# %%
df_acc_z
# Out:
#             0          1          2         3          4         5    \
# 0     -0.241627   7.148325   5.229665 -2.071770  -3.057416  1.547847
# 1     -0.260766  -1.430622   0.545455  1.284689  -1.064593 -0.291866
# 2     -0.260766   0.318182  -1.244019 -3.007177  -0.050239  1.232057
# 3     -0.167464  -1.241627  -2.255981 -0.224880   1.315789 -1.528708
# 4     -0.191388   0.688995  -0.102871  2.349282   0.643541  4.021531
# ...         ...        ...        ...       ...        ...       ...
# 2644   3.476077   1.107656   1.236842  2.327751  -0.389952  0.622010
# 2645  -0.349282  -0.925837   0.629187 -0.488038  -0.873206 -2.251196
# 2646   5.566986 -15.770335 -16.571770  2.366029  -1.564593 -9.521531
# 2647  -0.653110   2.217703   4.949761  1.602871   3.899522  0.772727
# 2648  11.428230  11.236842  -0.767943  3.418660  13.428230  3.325359
#
#            6          7         8         9    ...        390        391  \
# ...

# %%
labels = list(df_acc['label'].values)
z = []
for i in range(2649):
    z.append(labels[i*400])

# %%
df_acc_z['z']=z

# %%
df_acc_z
# Out:
#               0          1          2         3          4         5  \
# 0     -0.241627   7.148325   5.229665 -2.071770  -3.057416  1.547847
# 1     -0.260766  -1.430622   0.545455  1.284689  -1.064593 -0.291866
# 2     -0.260766   0.318182  -1.244019 -3.007177  -0.050239  1.232057
# 3     -0.167464  -1.241627  -2.255981 -0.224880   1.315789 -1.528708
# 4     -0.191388   0.688995  -0.102871  2.349282   0.643541  4.021531
# ...         ...        ...        ...       ...        ...       ...
# 2644   3.476077   1.107656   1.236842  2.327751  -0.389952  0.622010
# 2645  -0.349282  -0.925837   0.629187 -0.488038  -0.873206 -2.251196
# 2646   5.566986 -15.770335 -16.571770  2.366029  -1.564593 -9.521531
# 2647  -0.653110   2.217703   4.949761  1.602871   3.899522  0.772727
# 2648  11.428230  11.236842  -0.767943  3.418660  13.428230  3.325359
#
#              6          7         8         9  ...        391        392  \
# ...

# %% [markdown]
# ## Gyroscope y direction

# %%
df_gyro
# Out:
#           gyro_z    gyro_x    gyro_y  label  sampleNum
# 0       0.078723  1.382979 -0.037234      0          0
# 1       0.203191 -0.215957 -0.218085      0          0
# 2       0.060638  0.838298 -0.050000      0          0
# 3      -0.042553  0.610638 -0.374468      0          0
# 4       0.001064  0.442553 -0.219149      0          0
# ...          ...       ...       ...    ...        ...
# 529795 -0.038298  1.623404  0.287234      1       2648
# 529796  0.094681 -0.111702  0.093617      1       2648
# 529797 -0.029787  1.501064  0.421277      1       2648
# 529798  0.093617 -0.339362 -0.072340      1       2648
# 529799 -0.095745  0.938298  0.363830      1       2648
#
# [529800 rows x 5 columns]

# %%
gyro_y_arr = df_gyro['gyro_y'].values

# %%
gyro_y_list = gyro_y_arr.tolist()

# %%
list_of_list = []
for i in range(2649):
    temp = gyro_y_list[i*200:(i+1)*200]
    list_of_list.append(temp)

# %%
df_gyro_y = pd.DataFrame(list_of_list)

# %%
df_gyro_y
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.037234 -0.218085 -0.050000 -0.374468 -0.219149 -0.186170 -0.498936
# 1     0.025532 -0.002128  0.080851  0.059574  0.136170  0.053191 -0.139362
# 2     0.518085  0.407447  0.454255  0.531915  0.404255  0.304255  0.576596
# 3    -0.176596  0.113830 -0.258511  0.047872 -0.065957 -0.065957  0.013830
# 4     0.074468 -0.111702 -0.026596 -0.151064 -0.126596 -0.045745 -0.167021
# ...        ...       ...       ...       ...       ...       ...       ...
# 2644 -0.915957 -0.904255 -1.196809 -0.731915 -1.060638 -0.935106 -0.945745
# 2645  0.269149  0.514894  0.205319  0.750000 -0.074468  0.706383 -0.041489
# 2646 -0.030851 -0.751064 -0.359574 -0.692553 -1.026596 -0.188298 -0.790426
# 2647 -0.159574 -0.357447 -0.560638 -0.570213 -0.289362 -0.634043 -0.950000
# 2648 -0.713830 -1.227660 -0.678723 -0.738298 -1.078723 -0.864894 -0.487234
#
# ...

# %%
labels = list(df_gyro['label'].values)
y = []
for i in range(2649):
    y.append(labels[i*200])

# %%
df_gyro_y['y']=y

# %%
df_gyro_y
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.037234 -0.218085 -0.050000 -0.374468 -0.219149 -0.186170 -0.498936
# 1     0.025532 -0.002128  0.080851  0.059574  0.136170  0.053191 -0.139362
# 2     0.518085  0.407447  0.454255  0.531915  0.404255  0.304255  0.576596
# 3    -0.176596  0.113830 -0.258511  0.047872 -0.065957 -0.065957  0.013830
# 4     0.074468 -0.111702 -0.026596 -0.151064 -0.126596 -0.045745 -0.167021
# ...        ...       ...       ...       ...       ...       ...       ...
# 2644 -0.915957 -0.904255 -1.196809 -0.731915 -1.060638 -0.935106 -0.945745
# 2645  0.269149  0.514894  0.205319  0.750000 -0.074468  0.706383 -0.041489
# 2646 -0.030851 -0.751064 -0.359574 -0.692553 -1.026596 -0.188298 -0.790426
# 2647 -0.159574 -0.357447 -0.560638 -0.570213 -0.289362 -0.634043 -0.950000
# 2648 -0.713830 -1.227660 -0.678723 -0.738298 -1.078723 -0.864894 -0.487234
#
# ...

# %% [markdown]
# ## Gyroscope x direction

# %%
gyro_x_arr = df_gyro['gyro_x'].values

# %%
gyro_x_list = gyro_x_arr.tolist()

# %%
list_of_list = []
for i in range(2649):
    temp = gyro_x_list[i*200:(i+1)*200]
    list_of_list.append(temp)

# %%
df_gyro_x = pd.DataFrame(list_of_list)

# %%
df_gyro_x
# Out:
#            0         1         2         3         4         5         6    \
# 0     1.382979 -0.215957  0.838298  0.610638  0.442553  0.061702  0.343617
# 1    -0.036170 -0.095745 -0.026596 -0.037234  0.134043 -0.056383  0.380851
# 2    -0.310638 -0.023404  0.088298  0.267021  0.031915  0.353191  0.035106
# 3    -0.309574 -0.425532 -0.434043 -0.514894 -0.471277 -0.225532 -0.581915
# 4     0.222340  0.290426  0.000000  0.063830  0.076596 -0.036170 -0.028723
# ...        ...       ...       ...       ...       ...       ...       ...
# 2644 -0.204255 -0.642553 -1.843617 -0.948936 -1.315957 -1.796809 -0.985106
# 2645 -0.250000 -0.014894 -0.143617 -0.286170 -0.382979  0.258511  0.110638
# 2646 -0.481915  0.185106 -1.208511  2.037234  1.248936 -1.311702  1.852128
# 2647  0.317021  0.675532 -0.405319  0.254255  0.012766 -1.423404 -1.987234
# 2648 -2.190426  0.794681 -1.361702  0.363830 -2.251064  0.267021 -1.071277
#
# ...

# %%
labels = list(df_gyro['label'].values)
x = []
for i in range(2649):
    x.append(labels[i*200])

# %%
df_gyro_x['x']=x

# %%
df_gyro_x
# Out:
#              0         1         2         3         4         5         6  \
# 0     1.382979 -0.215957  0.838298  0.610638  0.442553  0.061702  0.343617
# 1    -0.036170 -0.095745 -0.026596 -0.037234  0.134043 -0.056383  0.380851
# 2    -0.310638 -0.023404  0.088298  0.267021  0.031915  0.353191  0.035106
# 3    -0.309574 -0.425532 -0.434043 -0.514894 -0.471277 -0.225532 -0.581915
# 4     0.222340  0.290426  0.000000  0.063830  0.076596 -0.036170 -0.028723
# ...        ...       ...       ...       ...       ...       ...       ...
# 2644 -0.204255 -0.642553 -1.843617 -0.948936 -1.315957 -1.796809 -0.985106
# 2645 -0.250000 -0.014894 -0.143617 -0.286170 -0.382979  0.258511  0.110638
# 2646 -0.481915  0.185106 -1.208511  2.037234  1.248936 -1.311702  1.852128
# 2647  0.317021  0.675532 -0.405319  0.254255  0.012766 -1.423404 -1.987234
# 2648 -2.190426  0.794681 -1.361702  0.363830 -2.251064  0.267021 -1.071277
#
# ...

# %% [markdown]
# ## Gyroscope z direction

# %%
gyro_z_arr = df_gyro['gyro_z'].values

# %%
gyro_z_list = gyro_z_arr.tolist()

# %%
list_of_list = []
for i in range(2649):
    temp = gyro_z_list[i*200:(i+1)*200]
    list_of_list.append(temp)

# %%
df_gyro_z = pd.DataFrame(list_of_list)

# %%
df_gyro_z
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.078723  0.203191  0.060638 -0.042553  0.001064 -0.030851 -0.072340
# 1    -0.052128  0.018085  0.093617  0.095745  0.061702  0.081915 -0.070213
# 2     0.203191  0.043617  0.178723  0.131915  0.145745  0.145745  0.192553
# 3    -0.032979  0.061702  0.010638  0.087234  0.045745  0.034043  0.109574
# 4     0.056383 -0.014894  0.004255  0.014894 -0.038298  0.021277 -0.001064
# ...        ...       ...       ...       ...       ...       ...       ...
# 2644  0.195745  0.277660  0.446809  0.415957  0.494681  0.552128  0.318085
# 2645  0.286170  0.252128  0.324468  0.380851  0.315957  0.248936  0.329787
# 2646  0.144681  0.250000  0.006383 -0.956383 -0.720213 -0.101064 -0.457447
# 2647  0.064894 -0.070213  0.092553 -0.213830 -0.076596  0.279787  0.163830
# 2648  0.148936 -0.143617  0.000000  0.006383  0.060638 -0.061702  0.046809
#
# ...

# %%
labels = list(df_gyro['label'].values)
z = []
for i in range(2649):
    z.append(labels[i*200])

# %%
df_gyro_z['z']=z

# %%
df_gyro_z
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.078723  0.203191  0.060638 -0.042553  0.001064 -0.030851 -0.072340
# 1    -0.052128  0.018085  0.093617  0.095745  0.061702  0.081915 -0.070213
# 2     0.203191  0.043617  0.178723  0.131915  0.145745  0.145745  0.192553
# 3    -0.032979  0.061702  0.010638  0.087234  0.045745  0.034043  0.109574
# 4     0.056383 -0.014894  0.004255  0.014894 -0.038298  0.021277 -0.001064
# ...        ...       ...       ...       ...       ...       ...       ...
# 2644  0.195745  0.277660  0.446809  0.415957  0.494681  0.552128  0.318085
# 2645  0.286170  0.252128  0.324468  0.380851  0.315957  0.248936  0.329787
# 2646  0.144681  0.250000  0.006383 -0.956383 -0.720213 -0.101064 -0.457447
# 2647  0.064894 -0.070213  0.092553 -0.213830 -0.076596  0.279787  0.163830
# 2648  0.148936 -0.143617  0.000000  0.006383  0.060638 -0.061702  0.046809
#
# ...

# %%
df_acc_y.to_csv('csv/df_acc_y.csv')
df_acc_x.to_csv('csv/df_acc_x.csv')
df_acc_z.to_csv('csv/df_acc_z.csv')
df_gyro_y.to_csv('csv/df_gyro_y.csv')
df_gyro_x.to_csv('csv/df_gyro_x.csv')
df_gyro_z.to_csv('csv/df_gyro_z.csv')
